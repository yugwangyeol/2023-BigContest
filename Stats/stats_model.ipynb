# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import OLSInfluence

# %% [markdown]
# ## Data Preprocessing

# %%
df_1 = pd.read_csv('../Data/train_1.csv')
df_2 = pd.read_csv('../Data/train_2.csv')
df_test = pd.read_csv('../Data/train_3.csv')
df_3 = pd.read_csv('../Data/test.csv')

# %%
# train data 병합

data = pd.concat([df_1,df_2,df_3])
data.columns = ["file_name",'name','height','weight','satba_time','play_time','rest_time','status','skill','move','game_num']
df_test.columns = ["file_name",'name','height','weight','satba_time','play_time','rest_time','status','skill','move','game_num']

# %%
# round 변수 생성

data['round'] = data['file_name'].apply(lambda x: x.split('_')[1])
df_test['round'] = df_test['file_name'].apply(lambda x: x.split('_')[1])

# %%
# 기존 12강으로 되어있는 경기를 16강으로 변경

data['round'] = data['round'].apply(lambda x: '16' if x=='12' else x)

# %% [markdown]
# ## Fit & Predict

# %%
# 독립 변수 : 키, 몸무게, 샅바 시간, 경기 시간, 휴식 시간, 기술 횟수, 이동 거리, round
# 종속 변수 : 누적 판수
# 다중 회귀 분석 적용

model = smf.ols('game_num ~ height+weight+satba_time+play_time+rest_time+skill+move+round', data = data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               game_num   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     355.4
# Date:                Sun, 12 Nov 2023   Prob (F-statistic):           1.08e-95
# Time:                        20:47:04   Log-Likelihood:                -105.84
# No. Observations:                 154   AIC:                             233.7
# Df Residuals:                     143   BIC:                             267.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.6195      1.976      0.820      0.414      -2.286       5.525
# round[T.2]    -0.0555      0.289     -0.192      0.848      -0.626       0.515
# round[T.4]    -0.1737      0.215     -0.809      0.420      -0.598       0.251
# round[T.8]    -0.3239      0.140     -2.321      0.022      -0.600      -0.048
# height        -0.0094      0.012     -0.763      0.447      -0.034       0.015
# weight         0.0027      0.004      0.753      0.452      -0.004       0.010
# satba_time     0.0011      0.001      2.229      0.027       0.000       0.002
# play_time     -0.0043      0.002     -2.029      0.044      -0.008      -0.000
# rest_time      0.0003    7.4e-05      3.580      0.000       0.000       0.000
# skill          0.1130      0.016      7.102      0.000       0.082       0.144
# move        9.691e-05   1.03e-05      9.367      0.000    7.65e-05       0.000
# ==============================================================================
# Omnibus:                        7.017   Durbin-Watson:                   1.709
# Prob(Omnibus):                  0.030   Jarque-Bera (JB):                6.851
# Skew:                           0.421   Prob(JB):                       0.0325
# Kurtosis:                       3.598   Cond. No.                     1.22e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.22e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df_test['predict']=model.predict(df_test.drop(["file_name","name","status","game_num"],axis=1))
df_test
# Out:
#      file_name name  height  weight  satba_time  play_time  rest_time  status  \
# 0   한라_8_1_1_0  이국희     183     106          51          6          0       0
# 1   한라_8_1_1_0  김무호     183     107          51          6          0       1
# 2   한라_8_1_2_0  이국희     183     106          99         12         60       0
# 3   한라_8_1_2_0  김무호     183     107          99         12         60       0
# 4   한라_8_2_1_0  유정훈     190     105          62          3          0       0
# 5   한라_8_2_1_0  최성환     183     107          62          3          0       1
# 6   한라_8_2_2_0  유정훈     190     105         112          9         60       0
# 7   한라_8_2_2_0  최성환     183     107         112          9         60       0
# 8   한라_8_3_1_0  박동환     193     105          50          9          0       0
# 9   한라_8_3_1_0  박민교     182     105          50          9          0       1
# 10  한라_8_3_2_0  박동환     193     105         107         16         60       0
# 11  한라_8_3_2_0  박민교     182     105         107         16         60       0
# 12  한라_8_4_1_0  남원택     183     108          49          2          0       0
# 13  한라_8_4_1_0  차민수     183     106          49          2          0       1
# 14  한라_8_4_2_0  남원택     183     108          85          6         60       0
# 15  한라_8_4_2_0  차민수     183     106          85          6         60       0
# 16  한라_4_1_1_0  김무호     183     107         186         21       1564       0
# 17  한라_4_1_1_0  최성환     183     107         199         18       1229       1
# 18  한라_4_1_2_0  김무호     183     107         248         31       1624       1
# 19  한라_4_1_2_0  최성환     183     107         261         28       1289       0
# 20  한라_4_1_3_0  김무호     183     107         296         36       1684       1
# 21  한라_4_1_3_0  최성환     183     107         309         33       1349       0
# 22  한라_4_2_1_0  박민교     182     105         159         17       1573       0
# 23  한라_4_2_1_0  차민수     183     106         137          7       1229       1
# 24  한라_4_2_2_0  박민교     182     105         207         24       1633       1
# 25  한라_4_2_2_0  차민수     183     106         185         14       1289       0
# 26  한라_4_2_3_0  박민교     182     105         260         28       1693       1
# 27  한라_4_2_3_0  차민수     183     106         238         18       1349       0
# 28  한라_2_1_1_0  김무호     183     107         338         38       2713       0
# 29  한라_2_1_1_0  차민수     183     106         280         20       1830       1
# 30  한라_2_1_2_0  김무호     183     107         376         48       2773       0
# 31  한라_2_1_2_0  차민수     183     106         318         30       1890       1
# 32  한라_2_2_1_0  최성환     183     107         363         35       3000       0
# 33  한라_2_2_1_0  박민교     182     105         314         30       2786       1
# 34  한라_2_2_2_0  최성환     183     107         411         95       3060       0
# 35  한라_2_2_2_0  박민교     182     105         362         90       2846       0
# 36  한라_2_2_2_1  최성환     183     107         453        100       3060       1
# 37  한라_2_2_2_1  박민교     182     105         404         95       2846       0
# 38  한라_2_2_3_0  최성환     183     107         497        103       3180       1
# 39  한라_2_2_3_0  박민교     182     105         448         98       2966       0
# 40  한라_2_2_4_0  최성환     183     107         548        112       3240       0
# 41  한라_2_2_4_0  박민교     182     105         499        107       3026       1
# 42  한라_2_2_5_0  최성환     183     107         591        119       3360       0
# 43  한라_2_2_5_0  박민교     182     105         542        114       3146       1
#
#     skill          move  game_num round   predict
# 0       1   4798.979413         1     8  0.475826
# 1       1   4798.979413         1     8  0.478499
# 2       2  11549.262830         2     8  1.287950
# 3       2  11549.262830         2     8  1.290622
# 4       1   3691.158295         1     8  0.325533
# 5       1   3691.158295         1     8  0.396428
# 6       4   8455.673135         2     8  1.173440
# 7       4   8455.673135         2     8  1.244335
# 8       3   5164.752321         1     8  0.626998
# 9       3   5164.752321         1     8  0.730005
# 10      6  10857.826810         2     8  1.568603
# 11      6  10857.826810         2     8  1.671610
# 12      2   3386.124295         1     8  0.471969
# 13      2   3386.124295         1     8  0.466623
# 14      5   6516.374497         2     8  1.154077
# 15      5   6516.374497         2     8  1.148731
# 16      5  15869.639860         3     4  2.657499
# 17      7  12776.050160         3     4  2.522487
# 18      9  20286.771440         4     4  3.581356
# 19     11  17193.181740         4     4  3.446344
# 20     10  24044.588570         5     4  4.107742
# 21     12  20950.998880         5     4  3.972730
# 22      7  15724.152650         3     4  2.862029
# 23      6  11382.700340         3     4  2.248042
# 24      9  22210.672380         4     4  3.757309
# 25      8  17869.220060         4     4  3.143322
# 26     11  27090.567590         5     4  4.515349
# 27     10  22749.115280         5     4  3.901363
# 28     11  27628.587180         6     2  4.998029
# 29     11  26333.113880         6     2  4.646511
# 30     15  33352.849750         7     2  6.021237
# 31     15  32057.376450         7     2  5.669719
# 32     14  25394.732970         6     2  5.237698
# 33     13  31534.301680         5     2  5.632531
# 34     22  31585.896160         7     2  6.556701
# 35     21  37725.464880         6     2  6.951534
# 36     25  35705.740760         8     2  7.321393
# 37     24  41845.309470         7     2  7.716226
# 38     27  40796.623540         9     2  8.109781
# 39     26  46936.192260         8     2  8.504613
# 40     30  44853.846200        10     2  8.877522
# 41     29  50993.414910         9     2  9.272354
# 42     32  48026.346040        11     2  9.461849
# 43     31  54165.914750        10     2  9.856682

# %% [markdown]
# ## TO CSV

# %%
df_test.to_csv('../Output/한라_predict.csv', index=False, encoding='cp949')
