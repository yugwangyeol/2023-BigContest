# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import OLSInfluence

# %% [markdown]
# ## Data Preprocessing

# %%
df_1 = pd.read_csv('../Data/train_1.csv')
df_2 = pd.read_csv('../Data/train_2.csv')
df_3 = pd.read_csv('../Data/train_3.csv')
df_test = pd.read_csv('../Data/test.csv')

# %%
# train data 병합

data = pd.concat([df_1,df_2,df_3])
data.columns = ["file_name",'name','height','weight','satba_time','play_time','rest_time','status','skill','move','game_num']
df_test.columns = ["file_name",'name','height','weight','satba_time','play_time','rest_time','status','skill','move','game_num']
# Out:
#       file_name name  height  weight  satba_time  play_time  rest_time  \
# 0   태백_12_1_1_0  손희찬     175      84          99          3          0
# 1   태백_12_1_1_0  이준호     172      82          99          3          0
# 2   태백_12_1_2_0  손희찬     175      84         174         11         60
# 3   태백_12_1_2_0  이준호     172      82         174         11         60
# 4   태백_12_1_3_0  손희찬     175      84         232         13        120
# ..          ...  ...     ...     ...         ...        ...        ...
# 39   한라_2_2_3_0  박민교     182     105         448         98       2966
# 40   한라_2_2_4_0  최성환     183     107         548        112       3240
# 41   한라_2_2_4_0  박민교     182     105         499        107       3026
# 42   한라_2_2_5_0  최성환     183     107         591        119       3360
# 43   한라_2_2_5_0  박민교     182     105         542        114       3146
#
#     status  skill         move  game_num
# 0        0      2   3559.90600         1
# 1        1      2   3559.90600         1
# 2        1      7   7353.33000         2
# 3        0      7   7353.33000         2
# 4        1      8  13551.63900         3
# ..     ...    ...          ...       ...
# 39       0     26  46936.19226         8
# 40       0     30  44853.84620        10
# 41       1     29  50993.41491         9
# 42       0     32  48026.34604        11
# 43       1     31  54165.91475        10
#
# [142 rows x 11 columns]

# %%
# round 변수 생성

data['round'] = data['file_name'].apply(lambda x: x.split('_')[1])
df_test['round'] = df_test['file_name'].apply(lambda x: x.split('_')[1])
# Out:
#      file_name name  height  weight  satba_time  play_time  rest_time  status  \
# 0  태백_12_1_1_0  손희찬     175      84          99          3          0       0
# 1  태백_12_1_1_0  이준호     172      82          99          3          0       1
# 2  태백_12_1_2_0  손희찬     175      84         174         11         60       1
# 3  태백_12_1_2_0  이준호     172      82         174         11         60       0
# 4  태백_12_1_3_0  손희찬     175      84         232         13        120       1
#
#    skill       move  game_num round
# 0      2   3559.906         1    12
# 1      2   3559.906         1    12
# 2      7   7353.330         2    12
# 3      7   7353.330         2    12
# 4      8  13551.639         3    12

# %%
# 기존 12강으로 되어있는 경기를 16강으로 변경

data['round'] = data['round'].apply(lambda x: '16' if x=='12' else x)

# %% [markdown]
# ## Fit & Predict

# %%
# 독립 변수 : 키, 몸무게, 샅바 시간, 경기 시간, 휴식 시간, 기술 횟수, 이동 거리, round
# 종속 변수 : 누적 판수
# 다중 회귀 분석 적용

model = smf.ols('game_num ~ height+weight+satba_time+play_time+rest_time+skill+move+round', data = data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               game_num   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     332.2
# Date:                Sun, 24 Sep 2023   Prob (F-statistic):           6.47e-88
# Time:                        15:27:34   Log-Likelihood:                -102.35
# No. Observations:                 142   AIC:                             226.7
# Df Residuals:                     131   BIC:                             259.2
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.